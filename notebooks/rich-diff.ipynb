# %%
from genai_demo.rich_diff import (
    TEST_OLD,
    TEST_NEW,
    RichDiff
)

# %%
diff = RichDiff(TEST_OLD, TEST_NEW)

# %%
diff.show()
# Out:
#  1    - │ def format_user(name, role):
#     1 + │ def format_user(name: str, role: str) -> str:
#  2    - │     return f"{name} ({role})"
#     2 + │     return f"{name} [{role}]"
#  3  3   │
#  4    - │ def can_access(role, resource):
#     4 + │ def can_access(role: str, resource: str) -> bool:
#  5    - │     if role == "admin":
#     5 + │     if role in ("admin", "owner"):
#  6  6   │         return True
#  7    - │     if role == "editor" and resource != "billing":
#     7 + │     if role == "editor" and resource not in ("billing", "secrets"):
#  8  8   │         return True
#  9  9   │     return False
# 10 10   │
# 11    - │ print(format_user("Sam", "editor"))
#    11 + │ # demo
#    12 + │ print(format_user("Sam", "owner"))
# <div style='overflow-x:auto'><!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <style>
#
# body {
#     color: #000000;
#     background-color: #ffffff;
# }
# </style>
# </head>
# <body>
# ...
